# %%
import pandas as pd

# %%
import numpy as np

# %%
n_rows = 100
n_cols = 5

data = np.random.randint(10, 110, size = (n_rows, n_cols))
data
# Out:
# array([[ 17,  50,  97,  34,  42],
#        [ 19,  45, 108,  32,  79],
#        [ 25,  22,  14,  67,  81],
#        [ 94,  60, 108,  84,  24],
#        [ 31,  78, 106,  28,  51],
#        [ 94,  14,  71,  61,  11],
#        [ 14,  36,  80,  30,  40],
#        [ 55,  33,  45,  66,  64],
#        [ 32,  40,  86,  88,  10],
#        [ 38,  98,  52,  66,  38],
#        [ 91,  21,  56,  35,  19],
#        [ 32,  89,  27,  56,  25],
#        [ 75,  15, 108,  99,  44],
#        [ 12,  60,  68, 109,  30],
#        [ 42, 104,  66,  32,  79],
#        [ 84,  29,  40,  86,  57],
#        [ 93,  42,  94,  41, 103],
#        [ 19,  72,  98,  26,  35],
#        [ 82, 102, 107,  45,  28],
#        [ 48, 107,  75,  59,  39],
#        [ 26,  88,  97,  95, 106],
#        [ 20,  41,  89,  92,  67],
#        [100,  64,  40,  53,  41],
#        [ 30, 109,  99,  37,  29],
#        [ 95,  79,  11,  27, 105],
#        [ 65,  81,  75,  53,  32],
#        [ 74,  94,  59,  56,  92],
# ...

# %%
pd.DataFrame(data, columns=tuple('ABCDE'))
# Out:
#       A   B    C    D    E
# 0    17  50   97   34   42
# 1    19  45  108   32   79
# 2    25  22   14   67   81
# 3    94  60  108   84   24
# 4    31  78  106   28   51
# ..  ...  ..  ...  ...  ...
# 95   78  18   26  100   25
# 96   72  73   64   73   89
# 97   70  17   44   35   42
# 98  109  66   39   30   88
# 99   83  93   36   19  102
#
# [100 rows x 5 columns]
